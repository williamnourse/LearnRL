# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
env = gym.make("LunarLander-v3")    # create the environment
observation, info = env.reset()    # reset the environment and get the initial observation

for _ in range(20):
    # Take a random action
    action = env.action_space.sample()
    print("Action taken:", action)

    # Step the environment with the action
    observation, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        observation, info = env.reset()    # reset the environment if the episode is terminated or truncated

env.close()    # close the environment
# Out:
# Action taken: 2
# Action taken: 2
# Action taken: 2
# Action taken: 2
# Action taken: 2
# Action taken: 3
# Action taken: 0
# Action taken: 2
# Action taken: 1
# Action taken: 1
# Action taken: 3
# Action taken: 0
# Action taken: 0
# Action taken: 3
# Action taken: 3
# Action taken: 0
# Action taken: 3
# Action taken: 0
# Action taken: 2
# Action taken: 3

# %%
env = gym.make("LunarLander-v3")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample()) # Get a random observation
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample()) # Take a random action

env.close()
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [ 1.4015865  -1.8197994  -1.7071233   9.701886   -4.299516   -8.280804
#   0.45701876  0.38026166]
#
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1

# %%
env = make_vec_env("LunarLander-v3", n_envs=16)
env.reset()
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device
# /home/will/LearnRL/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(

# %%
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v3"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91       |
# |    ep_rew_mean     | -175     |
# | time/              |          |
# |    fps             | 5801     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.5         |
# |    ep_rew_mean          | -149         |
# | time/                   |              |
# |    fps                  | 3625         |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0092520695 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.000701    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00559     |
# |    value_loss           | 4.78e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.7        |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 3222        |
# |    iterations           | 3           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008137111 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00107    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 615         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00662    |
# |    value_loss           | 1.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.2        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 3062        |
# |    iterations           | 4           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009372379 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0206     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 425         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 1.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 2954        |
# |    iterations           | 5           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010631502 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00335    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 362         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00638    |
# |    value_loss           | 859         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -107         |
# | time/                   |              |
# |    fps                  | 2883         |
# |    iterations           | 6            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0060275756 |
# |    clip_fraction        | 0.0307       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -0.00478     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 345          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00242     |
# |    value_loss           | 815          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -85.4        |
# | time/                   |              |
# |    fps                  | 2842         |
# |    iterations           | 7            |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0072631054 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.000338    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | -63.4        |
# | time/                   |              |
# |    fps                  | 2805         |
# |    iterations           | 8            |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0070146886 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.29        |
# |    explained_variance   | -0.000226    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 295          |
# |    n_updates            | 28           |
# |    policy_gradient_loss | -0.0046      |
# |    value_loss           | 617          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -50.3       |
# | time/                   |             |
# |    fps                  | 2765        |
# |    iterations           | 9           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.008117422 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -3.22e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 147         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00492    |
# |    value_loss           | 439         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | -32.1       |
# | time/                   |             |
# |    fps                  | 2734        |
# |    iterations           | 10          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.011505835 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -7.87e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 214         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 409         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 187          |
# |    ep_rew_mean          | -23.1        |
# | time/                   |              |
# |    fps                  | 2557         |
# |    iterations           | 11           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0068785553 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 231          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 429          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 244          |
# |    ep_rew_mean          | -29.7        |
# | time/                   |              |
# |    fps                  | 2452         |
# |    iterations           | 12           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0075498465 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 5.36e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 145          |
# |    n_updates            | 44           |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 438          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 242         |
# |    ep_rew_mean          | -41         |
# | time/                   |             |
# |    fps                  | 2341        |
# |    iterations           | 13          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.008185984 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 2.6e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 220         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 558         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 295          |
# |    ep_rew_mean          | -36.8        |
# | time/                   |              |
# |    fps                  | 2171         |
# |    iterations           | 14           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0055551245 |
# |    clip_fraction        | 0.0851       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.000213     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 365          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00408     |
# |    value_loss           | 567          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 388         |
# |    ep_rew_mean          | -32.8       |
# | time/                   |             |
# |    fps                  | 2005        |
# |    iterations           | 15          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.003351109 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.00272     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 178         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 377         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 476         |
# |    ep_rew_mean          | -26.3       |
# | time/                   |             |
# |    fps                  | 1906        |
# |    iterations           | 16          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.005585512 |
# |    clip_fraction        | 0.0353      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 127         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00212    |
# |    value_loss           | 336         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 513          |
# |    ep_rew_mean          | -30.3        |
# | time/                   |              |
# |    fps                  | 1812         |
# |    iterations           | 17           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0058822786 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 129          |
# |    n_updates            | 64           |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 393          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 558         |
# |    ep_rew_mean          | -23.2       |
# | time/                   |             |
# |    fps                  | 1727        |
# |    iterations           | 18          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005880315 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.562       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.2        |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.0023     |
# |    value_loss           | 253         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 581       |
# |    ep_rew_mean          | -17.7     |
# | time/                   |           |
# |    fps                  | 1670      |
# |    iterations           | 19        |
# |    time_elapsed         | 186       |
# |    total_timesteps      | 311296    |
# | train/                  |           |
# |    approx_kl            | 0.0070768 |
# |    clip_fraction        | 0.0416    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.24     |
# |    explained_variance   | 0.682     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 82.3      |
# |    n_updates            | 72        |
# |    policy_gradient_loss | -0.00232  |
# |    value_loss           | 199       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 641          |
# |    ep_rew_mean          | -9.05        |
# | time/                   |              |
# |    fps                  | 1636         |
# |    iterations           | 20           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0055047735 |
# |    clip_fraction        | 0.0257       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.1         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 203          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 667          |
# |    ep_rew_mean          | 6.1          |
# | time/                   |              |
# |    fps                  | 1598         |
# |    iterations           | 21           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0046113534 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.74         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.4         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 234          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 637          |
# |    ep_rew_mean          | 9.47         |
# | time/                   |              |
# |    fps                  | 1569         |
# |    iterations           | 22           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0052418383 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.869        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.9         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 100          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 693         |
# |    ep_rew_mean          | 23          |
# | time/                   |             |
# |    fps                  | 1534        |
# |    iterations           | 23          |
# |    time_elapsed         | 245         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.004210202 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.00173    |
# |    value_loss           | 136         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 731         |
# |    ep_rew_mean          | 32.6        |
# | time/                   |             |
# |    fps                  | 1501        |
# |    iterations           | 24          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.006247765 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.5        |
# |    n_updates            | 92          |
# |    policy_gradient_loss | -0.00126    |
# |    value_loss           | 66.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 778        |
# |    ep_rew_mean          | 46.8       |
# | time/                   |            |
# |    fps                  | 1464       |
# |    iterations           | 25         |
# |    time_elapsed         | 279        |
# |    total_timesteps      | 409600     |
# | train/                  |            |
# |    approx_kl            | 0.00647031 |
# |    clip_fraction        | 0.0523     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.868      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 18.6       |
# |    n_updates            | 96         |
# |    policy_gradient_loss | -0.00209   |
# |    value_loss           | 85.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 824          |
# |    ep_rew_mean          | 52.9         |
# | time/                   |              |
# |    fps                  | 1434         |
# |    iterations           | 26           |
# |    time_elapsed         | 296          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0057837316 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67           |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 48.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 863         |
# |    ep_rew_mean          | 57.4        |
# | time/                   |             |
# |    fps                  | 1410        |
# |    iterations           | 27          |
# |    time_elapsed         | 313         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.006358692 |
# |    clip_fraction        | 0.0516      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.42        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 42.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | 63.8        |
# | time/                   |             |
# |    fps                  | 1386        |
# |    iterations           | 28          |
# |    time_elapsed         | 330         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.007769031 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.3        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 49.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 932         |
# |    ep_rew_mean          | 77.3        |
# | time/                   |             |
# |    fps                  | 1367        |
# |    iterations           | 29          |
# |    time_elapsed         | 347         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.004498343 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.44        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 48.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 930         |
# |    ep_rew_mean          | 80.7        |
# | time/                   |             |
# |    fps                  | 1351        |
# |    iterations           | 30          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.007567159 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.18        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.000655   |
# |    value_loss           | 25.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 917          |
# |    ep_rew_mean          | 84.7         |
# | time/                   |              |
# |    fps                  | 1340         |
# |    iterations           | 31           |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0061931247 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.7         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 33.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 924         |
# |    ep_rew_mean          | 93.1        |
# | time/                   |             |
# |    fps                  | 1330        |
# |    iterations           | 32          |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 524288      |
# | train/                  |             |
# |    approx_kl            | 0.004578843 |
# |    clip_fraction        | 0.0398      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 27.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 943          |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 1320         |
# |    iterations           | 33           |
# |    time_elapsed         | 409          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0052982634 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.98         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | 0.000333     |
# |    value_loss           | 17.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 943          |
# |    ep_rew_mean          | 109          |
# | time/                   |              |
# |    fps                  | 1313         |
# |    iterations           | 34           |
# |    time_elapsed         | 424          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0034446276 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.28         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -2.69e-05    |
# |    value_loss           | 23.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 956          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 1307         |
# |    iterations           | 35           |
# |    time_elapsed         | 438          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0037677193 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.971       |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.59         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.000568    |
# |    value_loss           | 19           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 961          |
# |    ep_rew_mean          | 119          |
# | time/                   |              |
# |    fps                  | 1298         |
# |    iterations           | 36           |
# |    time_elapsed         | 454          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0072709825 |
# |    clip_fraction        | 0.0635       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.987       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.48         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000824    |
# |    value_loss           | 9.89         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 960         |
# |    ep_rew_mean          | 121         |
# | time/                   |             |
# |    fps                  | 1294        |
# |    iterations           | 37          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.004512443 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.995      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | 0.000367    |
# |    value_loss           | 17.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 952         |
# |    ep_rew_mean          | 122         |
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 38          |
# |    time_elapsed         | 482         |
# |    total_timesteps      | 622592      |
# | train/                  |             |
# |    approx_kl            | 0.004677546 |
# |    clip_fraction        | 0.0224      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.2        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.000201   |
# |    value_loss           | 12.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | 128         |
# | time/                   |             |
# |    fps                  | 1284        |
# |    iterations           | 39          |
# |    time_elapsed         | 497         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.005271542 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 152         |
# |    policy_gradient_loss | -0.000538   |
# |    value_loss           | 24.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 971          |
# |    ep_rew_mean          | 130          |
# | time/                   |              |
# |    fps                  | 1278         |
# |    iterations           | 40           |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0042039184 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.944       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.05         |
# |    n_updates            | 156          |
# |    policy_gradient_loss | 0.000675     |
# |    value_loss           | 9.04         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 965          |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 1273         |
# |    iterations           | 41           |
# |    time_elapsed         | 527          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0051701935 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.912       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.19         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000749    |
# |    value_loss           | 7.03         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 966          |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 1270         |
# |    iterations           | 42           |
# |    time_elapsed         | 541          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0034658974 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.13         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 15.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 972         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 1266        |
# |    iterations           | 43          |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 704512      |
# | train/                  |             |
# |    approx_kl            | 0.004083484 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.1        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.000598   |
# |    value_loss           | 19.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 986          |
# |    ep_rew_mean          | 134          |
# | time/                   |              |
# |    fps                  | 1261         |
# |    iterations           | 44           |
# |    time_elapsed         | 571          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0040948046 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.86        |
# |    explained_variance   | 0.974        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -8.91e-05    |
# |    value_loss           | 33.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 975          |
# |    ep_rew_mean          | 139          |
# | time/                   |              |
# |    fps                  | 1257         |
# |    iterations           | 45           |
# |    time_elapsed         | 586          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0045091966 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.65         |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.000912    |
# |    value_loss           | 4.52         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 958         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 1254        |
# |    iterations           | 46          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.006246086 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.802      |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 230         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00261    |
# |    value_loss           | 109         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 936          |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 1252         |
# |    iterations           | 47           |
# |    time_elapsed         | 614          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0029308805 |
# |    clip_fraction        | 0.0232       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.763       |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.5         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.000889    |
# |    value_loss           | 78.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 904         |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 1254        |
# |    iterations           | 48          |
# |    time_elapsed         | 627         |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.003120051 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.73       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.2        |
# |    n_updates            | 188         |
# |    policy_gradient_loss | -0.00133    |
# |    value_loss           | 121         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 850          |
# |    ep_rew_mean          | 165          |
# | time/                   |              |
# |    fps                  | 1254         |
# |    iterations           | 49           |
# |    time_elapsed         | 640          |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0050746994 |
# |    clip_fraction        | 0.0549       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.723       |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.8         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 149          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 758          |
# |    ep_rew_mean          | 179          |
# | time/                   |              |
# |    fps                  | 1255         |
# |    iterations           | 50           |
# |    time_elapsed         | 652          |
# |    total_timesteps      | 819200       |
# | train/                  |              |
# |    approx_kl            | 0.0037764837 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 114          |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 204          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 611        |
# |    ep_rew_mean          | 196        |
# | time/                   |            |
# |    fps                  | 1258       |
# |    iterations           | 51         |
# |    time_elapsed         | 663        |
# |    total_timesteps      | 835584     |
# | train/                  |            |
# |    approx_kl            | 0.00942949 |
# |    clip_fraction        | 0.0778     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.73      |
# |    explained_variance   | 0.693      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 93.8       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00402   |
# |    value_loss           | 331        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 477          |
# |    ep_rew_mean          | 199          |
# | time/                   |              |
# |    fps                  | 1262         |
# |    iterations           | 52           |
# |    time_elapsed         | 674          |
# |    total_timesteps      | 851968       |
# | train/                  |              |
# |    approx_kl            | 0.0051412387 |
# |    clip_fraction        | 0.0583       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.755       |
# |    explained_variance   | 0.557        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 140          |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 373          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 454          |
# |    ep_rew_mean          | 203          |
# | time/                   |              |
# |    fps                  | 1263         |
# |    iterations           | 53           |
# |    time_elapsed         | 687          |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0052719023 |
# |    clip_fraction        | 0.0631       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.802       |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 210          |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.000779    |
# |    value_loss           | 342          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 440          |
# |    ep_rew_mean          | 228          |
# | time/                   |              |
# |    fps                  | 1268         |
# |    iterations           | 54           |
# |    time_elapsed         | 697          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0049165236 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.738       |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.6         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 213          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 392         |
# |    ep_rew_mean          | 239         |
# | time/                   |             |
# |    fps                  | 1272        |
# |    iterations           | 55          |
# |    time_elapsed         | 708         |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.004716377 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83.1        |
# |    n_updates            | 216         |
# |    policy_gradient_loss | -0.000569   |
# |    value_loss           | 146         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 369         |
# |    ep_rew_mean          | 246         |
# | time/                   |             |
# |    fps                  | 1279        |
# |    iterations           | 56          |
# |    time_elapsed         | 717         |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.004704523 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000982   |
# |    value_loss           | 74.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 362          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 1284         |
# |    iterations           | 57           |
# |    time_elapsed         | 727          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0039569093 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.511        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.5         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 87.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 1290         |
# |    iterations           | 58           |
# |    time_elapsed         | 736          |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0046454086 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.786       |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.36         |
# |    n_updates            | 228          |
# |    policy_gradient_loss | 0.000149     |
# |    value_loss           | 25           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 1296         |
# |    iterations           | 59           |
# |    time_elapsed         | 745          |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0045954986 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | 0.728        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.72         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -9.63e-05    |
# |    value_loss           | 88.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 359          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 1302         |
# |    iterations           | 60           |
# |    time_elapsed         | 754          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0043348838 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.75        |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.04         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.000279    |
# |    value_loss           | 19.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 1309         |
# |    iterations           | 61           |
# |    time_elapsed         | 763          |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0030956194 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.707       |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.1         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000666    |
# |    value_loss           | 147          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 342          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 1314         |
# |    iterations           | 62           |
# |    time_elapsed         | 772          |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0072083715 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.753       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.9          |
# |    n_updates            | 244          |
# |    policy_gradient_loss | -0.000292    |
# |    value_loss           | 22.6         |
# ------------------------------------------

# %%
eval_env = Monitor(gym.make("LunarLander-v3", render_mode='rgb_array'))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=219.94 +/- 62.86717103634923
